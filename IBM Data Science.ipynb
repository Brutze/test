# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hagen von Tronje**

# %% [markdown]
# *I am interested in data science because I always loved data and statistics. I want to make it my profession.*

# %% [markdown]
# ### My code multiplies the numbers that are put in by the user

# %%
print("Type a number")
p = input()
p = int(p)
print("Type a second number")
q = input()
q = int(q)
p*q
# Out:
# Type a number
# 3
# Type a second number
# 5
# 15

# %% [markdown]
# * bulleted list
# * bulleted list
# * bulleted list
#
# ***
#
# 1. numbered list
# 2. numbered list
# 3. numbered list
#
# ***
#
# `Here is some code!`
